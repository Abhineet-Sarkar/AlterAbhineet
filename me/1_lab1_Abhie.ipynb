# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
gemini_api_key = os.getenv('GEMINI_API_KEY')

if gemini_api_key:
    print(f"Gemini API Key exists and begins {gemini_api_key[:8]}")
else:
    print("Gemini API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Gemini API Key exists and begins AQ.Ab8RN

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder

from google import genai

# %%
# And now we'll create an instance of the Gemini GenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

gemini_client = genai.Client(api_key=gemini_api_key)
print("Success!")
# Out:
# Success!

# %%
response = gemini_client.models.generate_content(
    model="gemini-3.5-flash",
    contents=[
        {"role": "user", "parts": [{"text": "What is 2+2?"}]},
    ]
)
print(response.text)
# Out:
# 2 + 2 = 4

# %%
question1="please pick up a business area or process on how agents are recruited in a life insurance industry. Can Agentic AI can be applied in that area ? Respond with one business area or process"

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        {"role": "user", "parts": [{"text": question1}]},
    ]
)
print(response.text)
# Out:
# **Business Area/Process:** Initial Candidate Screening and Qualification
#
# **How Agentic AI Can Be Applied:**
#
# The initial screening and qualification phase for life insurance agents is often high-volume, repetitive, and crucial for identifying individuals with the specific blend of sales acumen, resilience, communication skills, and ethical understanding required for success (and to reduce high agent attrition rates).
#
# An Agentic AI system can be applied here to autonomously and dynamically assess candidates far beyond traditional keyword matching:
#
# 1.  **Dynamic Profile Analysis and Scoring:**
#     *   **Agentic Action:** The AI agent ingests resumes, application forms, and potentially social media profiles (with consent). It doesn't just match keywords; it *reasons* about career trajectories, identifies patterns indicative of sales potential (e.g., entrepreneurial experience, customer-facing roles, rapid promotions), and assesses soft skills by analyzing language used in past job descriptions or personal statements (e.g., leadership, problem-solving, communication). It can also cross-reference for red flags or compliance issues.
#     *   **Why it's Agentic:** It makes independent judgments based on a complex understanding of various data points, rather than a pre-programmed rule set. It acts as an autonomous "initial assessor."
#
# 2.  **Conversational Pre-qualification and Assessment:**
#     *   **Agentic Action:** The AI agent initiates an interactive, personalized dialogue with candidates (via chatbot, voice bot, or email). Instead of fixed questions, it adaptively asks follow-up questions based on the candidate's previous answers, delves into specific experiences, gauges understanding of the life insurance sales role (e.g., commission structure, required licensing, ethical considerations), and assesses communication skills, persuasiveness, and resilience through the interaction itself. It can detect hesitation, evasiveness, or genuine enthusiasm.
#     *   **Why it's Agentic:** It uses natural language processing and generation to conduct a dynamic, goal-oriented conversation, adapting its strategy in real-time to extract relevant information and evaluate critical traits. It autonomously steers the conversation towards qualification criteria.
#
# 3.  **Predictive Success Modeling:**
#     *   **Agentic Action:** The AI agent integrates all collected data (profile analysis, conversational assessment, potentially short cognitive or behavioral tests). It then uses historical data of successful vs. unsuccessful agents within the company (e.g., time to license, first-year sales, retention rates) to generate a predictive score for each candidate, indicating their likelihood of success in the role. It can highlight specific areas of strength or weakness.
#     *   **Why it's Agentic:** It makes a data-driven prediction based on complex patterns, continuously learning and refining its model as more agent performance data becomes available, autonomously improving its accuracy over time.
#
# 4.  **Autonomous Scheduling and Routing:**
#     *   **Agentic Action:** Based on the qualification score and predictive success modeling, the AI agent autonomously schedules the most promising candidates for the next stage (e.g., human interview with a specific hiring manager) by checking calendars and sending personalized invitations. It can also send tailored rejection emails to unqualified candidates, or provide resources for those who might be suitable for other roles.
#     *   **Why it's Agentic:** It takes proactive action (scheduling, communication) based on its own assessments and predefined criteria, managing the flow of candidates without constant human intervention.
#
# By applying Agentic AI to initial screening and qualification, life insurance companies can significantly reduce time-to-hire, improve the quality of new recruits, lower agent attrition, and free up human recruiters to focus on high-value interactions with the most promising candidates.

# %%
question2="now pick the area or process of agent recruitment in life insurance industry and share a challenging pain point that can be solved using Agentic AI. Respond with only one pain point"

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        {"role": "user", "parts": [{"text": question2}]},
    ]
)
print(response.text)
# Out:
# The current recruitment process struggles to accurately predict the long-term success and retention of new life insurance agents, leading to high training costs and significant churn within the first 1-2 years.

# %%
question3="Propose an Agentic AI solution to the pain point that you have suggested : The current recruitment process struggles to accurately predict the long-term success and retention of new life insurance agents, leading to high training costs and significant churn within the first 1-2 years."

response = gemini_client.models.generate_content(
    model="gemini-3.1-flash-lite",
    contents=[
        {"role": "user", "parts": [{"text": question3}]},
    ]
)
print(response.text)
# Out:
# To address the high churn and poor long-term retention of life insurance agents, I propose an Agentic AI system called **"TalentCompass AI."**
#
# Unlike traditional applicant tracking systems (ATS) that rely on static resumes, **TalentCompass** uses a multi-agent orchestration layer to simulate candidate performance, stress-test their psychological fit, and predict their "longevity trajectory."
#
# ---
#
# ### The Architecture: Multi-Agent Orchestration
#
# The system functions through four specialized autonomous agents working in a feedback loop:
#
# #### 1. The "Persona Simulator" Agent (Role-Play Engine)
# Instead of a simple interview, this agent conducts an interactive, multi-stage simulation.
# *   **The Action:** The agent engages the candidate in a persistent, complex sales simulation (e.g., handling a "cold" lead, navigating a difficult objection from an actor-agent, and explaining a complex policy).
# *   **The Metric:** It tracks not just *what* they say, but their emotional regulation, resilience under pressure, and how quickly they pivot when faced with a "no."
#
# #### 2. The "Cognitive Profiler" Agent (Behavioral Analytics)
# Life insurance is a business of rejection. This agent analyzes the metadata from the simulation.
# *   **The Action:** It runs a latent trait analysis on the candidate’s responses to identify the "Grit Quotient"—assessing internal locus of control, delayed gratification, and empathy.
# *   **The Metric:** It cross-references these traits against a "Top Producer" dataset (data from agents who remained at the firm for 5+ years) to find high-correlation markers.
#
# #### 3. The "Risk-of-Exit" Predictive Agent (Retention Engine)
# This agent looks at extrinsic factors that usually trigger early churn.
# *   **The Action:** It audits the candidate’s social footprint (professional networking, past roles) and their answers regarding motivation (e.g., "Are they seeking a quick commission or a career?").
# *   **The Metric:** It generates a **Retention Probability Score (RPS)**. If the score is low, the agent flags potential "red flags" (e.g., high volatility in previous jobs, lack of community network) that recruiters might miss.
#
# #### 4. The "Coach-Match" Agent (Onboarding Orchestrator)
# The first 90 days are critical. This agent doesn't just hire; it assigns.
# *   **The Action:** Based on the candidate’s psychological profile, this agent matches the new hire with a specific mentor whose coaching style perfectly complements the new agent's weaknesses.
# *   **The Metric:** It creates a "Hyper-Personalized Onboarding Map," telling the manager exactly where this specific individual is likely to struggle in Month 3, allowing for proactive, rather than reactive, intervention.
#
# ---
#
# ### How it solves the pain point
#
# 1.  **From CV-Filtering to Simulation-Based Hiring:** By moving away from "years of experience" (which is a poor predictor of insurance sales success) to "demonstrated resilience," the system eliminates candidates who look good on paper but lack the grit for the industry.
# 2.  **Reducing Training Waste:** Because the **Coach-Match Agent** identifies an individual’s potential pitfalls *before* they happen, the firm can provide targeted support rather than generic training, lowering the cost of onboarding people who would have inevitably quit.
# 3.  **Predictive Offboarding/Intervention:** The **Risk-of-Exit Agent** acts as an early-warning system. By monitoring performance dips in real-time during the first year, it alerts managers to reach out *before* the agent reaches the point of no return.
#
# ### The Value Proposition
# *   **Reduction in Sunk Costs:** By cutting the bottom 20% of "high-churn-risk" candidates during the interview phase, firms save thousands in licensing, training, and base-salary draws.
# *   **Higher ROI per Hire:** By matching agents with managers whose styles improve retention, the firm increases the "lifetime value" of each successful recruit.
#
# **The "Agentic" Difference:** Unlike a standard algorithm that gives a "Yes/No" score, TalentCompass AI is an **autonomous recruiter** that adjusts its questions based on the candidate's responses in real-time, effectively functioning as a senior HR partner that never sleeps.

# %% [markdown]
# question="please pick up a business area or process on how agents are recruited in a life insurance industry. Can Agentic AI can be applied in that area ? Respond with one business area or process"
# messages = [{"role:}]

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)

# %%
from IPython.display import Markdown, display

display(Markdown(answer))

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Something here"}]

# Then make the first call:

response =

# Then read the business idea:

business_idea = response.

# And repeat! In the next message, include the business idea within the message
